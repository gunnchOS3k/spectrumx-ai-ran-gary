# %%
from pathlib import Path
import os
import numpy as np

# Show kernel working directory
print("CWD:", os.getcwd())

# Use absolute path to avoid CWD mismatches
data_dir = Path(r"C:\Users\anany\NSF project\spectrumx-ai-ran-gary\competition_dataset")
print("Data dir exists:", data_dir.exists())

# Look for .npy anywhere under competition_dataset
files = list(data_dir.rglob("*.npy"))
print("Total .npy under competition_dataset:", len(all_npy))
# Out:
# CWD: c:\Users\anany\NSF project\spectrumx-ai-ran-gary\notebooks
# Data dir exists: True
# Total .npy under competition_dataset: 240

# %%
import numpy as np

x = np.load(files[0])
x.shape, x.dtype
# Out:
# ((10000000,), dtype('complex64'))

# %%
x
# Out:
# array([-0.00660876+0.00715921j, -0.02640856+0.04521474j,
#         0.03267185+0.00493225j, ..., -0.01033504+0.00500867j,
#        -0.00057141+0.00498597j,  0.02997484+0.05523841j],
#       shape=(10000000,), dtype=complex64)
