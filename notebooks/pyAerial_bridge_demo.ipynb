# %% [markdown]
# # pyAerial bridge demo (honest scope)
#
# This notebook is **optional**. It does **not** install pyAerial or run cuPHY.
#
# - Run from **repo root** with `PYTHONPATH=.` so `src` resolves.
# - Streamlit Cloud remains **manifest + probe** only; PHY runs in **external** NVIDIA Aerial environments.

# %%
from src.edge_ran_gary.pyaerial_bridge import (
    cumac_scheduler_abstraction,
    describe_pyaerial_environment,
    detector_to_phy_control_plane_hints,
    suggested_integration_paths,
)

describe_pyaerial_environment()

# %%
# Example: occupancy belief -> PHY control-plane *hints* (not a wire protocol)
detector_to_phy_control_plane_hints(
    occupancy_label=1,
    confidence=0.62,
    scenario_traffic_score=0.55,
    rf_stress=0.4,
)

# %%
cumac_scheduler_abstraction(), suggested_integration_paths()
